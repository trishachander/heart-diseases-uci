# %%
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('heart.csv')

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
#information about attributes

#age
#sex
#chest pain
#resting blood pressure
#cholestoral
#fasting blood sugar
#resting electrocardiographic results
#maximum heart rate achieved
#exercise induced angina
#oldpeak = ST depression induced by exercise relative to rest
#the slope of the peak exercise ST segment
#number of major vessels (0-3) colored by flourosopy
#thal
#target - if there is heart disease or not

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
# age         303 non-null int64
# sex         303 non-null int64
# cp          303 non-null int64
# trestbps    303 non-null int64
# chol        303 non-null int64
# fbs         303 non-null int64
# restecg     303 non-null int64
# thalach     303 non-null int64
# exang       303 non-null int64
# oldpeak     303 non-null float64
# slope       303 non-null int64
# ca          303 non-null int64
# thal        303 non-null int64
# target      303 non-null int64
# dtypes: float64(1), int64(13)
# memory usage: 33.2 KB

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
sb.set(font_scale=1.25)
fig, ax = plt.subplots(figsize=(20,20))
sb.heatmap(df.corr(), annot = True,cmap="YlGnBu")

# %%
sb.countplot(df['sex'])

#0-male
#1-female

'This shows that females are more susceptible to heart diseases'
# Out:
# 'This shows that females are more susceptible to heart diseases'

# %%
sb.countplot(df['target'])

'More people have heart diseases'
# Out:
# 'More people have heart diseases'

# %%
sb.countplot(x='target',hue='sex',data=df)

# %%
sb.factorplot('age', kind='count', hue='target', data=df,height=20, aspect=.8)

# %%
plt.figure(figsize=(20,4))
sb.countplot(df['age'])

'People between the ages 41 to 67 are more prone to heart diseases.'
'The number of people having a heart disease is maximum when age is 58'

# %%
plt.figure(figsize=(8,8))
sb.scatterplot(x=df['age'],y=df['thalach'],hue=df['target'])
plt.xlabel('age')
plt.ylabel('thalach')
plt.show()

# %%
'df.cp.unique()'
sb.countplot(df['cp'])
'More people have type 0 chest pain'
# Out:
# 'More people have type 0 chest pain'

# %%
df1 = df

# %%
df1.drop(['sex','trestbps','fbs','restecg','thal','oldpeak','slope','ca','cp','target','exang'],axis=1,inplace=True)

# %%
df1 = pd.concat([df],axis=1)

# %%
sb.lmplot(x='thalach',y='age',data=df1)

'Age and heart rate relation is inverse.'
